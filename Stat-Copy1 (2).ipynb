# %%
import numpy as np
from collections import Counter
pois = np.random.poisson(10, 1000)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#plot = plt.hist(pois, 14, density=True)
sns.distplot(pois, hist=False, label='poisson')
plt.show()

# %%
from scipy.stats import chisquare, poisson

# %%
binom = np.random.binomial(n=1000, p=0.01, size=1000)

# %%
sns.distplot(pois, hist=False, label='poisson')
sns.distplot(binom, hist=False, label='binomial')


plt.show()

# %%
print(np.mean(pois))
# Out:
# 9.832

# %%
print(np.mean(binom))
# Out:
# 9.968

# %%
pois2 = np.random.poisson(20, 1000)

# %%
sns.distplot(pois, hist=False, label='poisson')
sns.distplot(pois2, hist=False, label='poisson2')


plt.show()

# %%
norm = np.random.normal(size=1000)
sns.distplot(norm, hist=False, label='norm')


plt.show()

# %% [markdown]
# ### HW

# %% [markdown]
# #### 1.
# #### 2.

# %% [markdown]
#  I genereted different distribution, including poisson with two different parameters. To test poisson distribution I goin to use chi^2 testing approach(Pearson). There is a function from library scipy chisquare. It needs in calculating frequencies. I gonna do it with np.histogram.

# %%
f_exp = np.histogram(pois)[0]

# %%
f_obs = np.histogram(pois2)[0]

# %%
from scipy.stats import chisquare, poisson

# %%
chisquare(f_obs = f_obs, f_exp = f_exp)
# Out:
# Power_divergenceResult(statistic=143.02152651665685, pvalue=2.4513243408227327e-26)

# %%
pois3 = np.random.poisson(20, 1000)

# %%
f_obs2 = np.histogram(pois3)[0]

# %%
chisquare(f_obs = f_obs2, f_exp = f_exp)
# Out:
# Power_divergenceResult(statistic=1147.3489232765178, pvalue=2.809862407257027e-241)

# %% [markdown]
# I tried
